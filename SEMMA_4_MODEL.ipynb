# %% [markdown]
# ### MODEL Phase

# %% [markdown]
# In the Model phase, we train a Logistic Regression model on the TF-IDF features and evaluate its performance using accuracy and F1-score metrics.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Prepare feature set and target
X_semma = tfidf_features  # Use TF-IDF features
y_semma = df_semma['sentiment_encoded']  # Encoded sentiment labels

# Train-Test Split
X_train_semma, X_test_semma, y_train_semma, y_test_semma = train_test_split(X_semma, y_semma, test_size=0.2, random_state=42)

# Train Logistic Regression model
logreg_semma = LogisticRegression(max_iter=1000, random_state=42)
logreg_semma.fit(X_train_semma, y_train_semma)

# Predict and evaluate
y_pred_semma = logreg_semma.predict(X_test_semma)
accuracy_semma = accuracy_score(y_test_semma, y_pred_semma)
classification_report_semma = classification_report(y_test_semma, y_pred_semma, target_names=label_encoder.classes_)

print("Accuracy:", accuracy_semma)
# Out:
# Accuracy: 0.6772197962154294
