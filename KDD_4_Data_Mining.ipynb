# %% [markdown]
# ### Data Mining

# %% [markdown]
# In this phase, we train a Logistic Regression model to classify the sentiment of tweets. The model's performance is evaluated on a test set using accuracy, precision, recall, and F1-score metrics.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Define features and target
X_kdd = tfidf_features_kdd
y_kdd = df_kdd['sentiment_encoded']

# Train-test split
X_train_kdd, X_test_kdd, y_train_kdd, y_test_kdd = train_test_split(X_kdd, y_kdd, test_size=0.2, random_state=42)

# Train Logistic Regression model
logreg_kdd = LogisticRegression(max_iter=1000, random_state=42)
logreg_kdd.fit(X_train_kdd, y_train_kdd)

# Predict and evaluate
y_pred_kdd = logreg_kdd.predict(X_test_kdd)
accuracy_kdd = accuracy_score(y_test_kdd, y_pred_kdd)
classification_report_kdd = classification_report(y_test_kdd, y_pred_kdd, target_names=label_encoder.classes_)

print("Accuracy:", accuracy_kdd)
# Out:
# Accuracy: 0.6772197962154294
