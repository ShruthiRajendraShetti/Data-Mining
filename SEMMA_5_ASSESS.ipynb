# %% [markdown]
# ### ASSESS Phase

# %% [markdown]
# In the Assess phase, we evaluate the model's performance and discuss its strengths and weaknesses, particularly focusing on class imbalance and potential improvements.
