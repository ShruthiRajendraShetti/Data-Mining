# %% [markdown]
# ### Transformation Phase

# %% [markdown]
# In the transformation phase, we convert the text into numerical format using TF-IDF vectorization and scale additional features like text length if needed.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

# TF-IDF Vectorization
tfidf_vectorizer_kdd = TfidfVectorizer(max_features=1000)
tfidf_features_kdd = tfidf_vectorizer_kdd.fit_transform(df_kdd['cleaned_text'])

# Optional scaling for text length feature
df_kdd['text_length'] = df_kdd['cleaned_text'].apply(len)
scaler_kdd = StandardScaler()
df_kdd['scaled_text_length'] = scaler_kdd.fit_transform(df_kdd[['text_length']])

# Display transformed data
df_kdd[['cleaned_text', 'sentiment_encoded', 'text_length', 'scaled_text_length']].head()
# Out:
#                                         cleaned_text  sentiment_encoded  \
# 0                  id have responded if i were going                  1
# 1         sooo sad i will miss you here in san diego                  0
# 2                             my boss is bullying me                  0
# 3                      what interview leave me alone                  0
# 4  sons of  why couldnt they put them on the rele...                  0
#
#    text_length  scaled_text_length
# 0           33           -0.891151
# 1           42           -0.626421
# 2           22           -1.214709
# 3           29           -1.008809
# 4           68            0.138354
