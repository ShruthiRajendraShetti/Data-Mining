# %% [markdown]
# ### Selection Phase

# %% [markdown]
# In this phase, we select the relevant data columns and ensure that there are no missing values in key fields like 'text' and 'sentiment'. We focus on these columns since they are essential for our sentiment analysis.

# %%
import pandas as pd

# Load dataset
file_path = '/content/train.csv'
df_kdd = pd.read_csv(file_path)

# Selection: Remove missing values in key columns
df_kdd = df_kdd.dropna(subset=['text', 'sentiment'])
df_kdd.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
