# %%
# Text cleaning, handling missing values, and encoding sentiments
import re
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer

# Drop missing values
df = df.dropna(subset=['text', 'selected_text'])

# Encode Sentiment labels
label_encoder = LabelEncoder()
df['sentiment_encoded'] = label_encoder.fit_transform(df['sentiment'])

# Feature Engineering: Length of text
df['text_length'] = df['text'].astype(str).apply(len)
df['selected_text_length'] = df['selected_text'].astype(str).apply(len)

# Standardization of text length
scaler = StandardScaler()
df[['scaled_text_length', 'scaled_selected_text_length']] = scaler.fit_transform(df[['text_length', 'selected_text_length']])

# TF-IDF vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=1000)
tfidf_features_sparse = tfidf_vectorizer.fit_transform(df['text'])

# %%
print(df.columns)
# Out:
# Index(['textID', 'text', 'selected_text', 'sentiment', 'sentiment_encoded',
#        'text_length', 'selected_text_length', 'scaled_text_length',
#        'scaled_selected_text_length'],
#       dtype='object')

# %%
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27480 entries, 0 to 27480
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   textID                       27480 non-null  object
#  1   text                         27480 non-null  object
#  2   selected_text                27480 non-null  object
#  3   sentiment                    27480 non-null  object
#  4   sentiment_encoded            27480 non-null  int64
#  5   text_length                  27480 non-null  int64
#  6   selected_text_length         27480 non-null  int64
#  7   scaled_text_length           27480 non-null  float64
#  8   scaled_selected_text_length  27480 non-null  float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 2.1+ MB
# None
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# ...
